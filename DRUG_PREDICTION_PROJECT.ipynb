# %% [markdown]
# # DRUG PREDICTION USING MACHINE LEARNING
#
# ## A Data Analysis and Multi-Class Classification Project

# %% [markdown]
# # 1. Project Introduction
#
# Drug prescription plays an important role in healthcare, as the appropriate medicine may vary depending on the characteristics of a patient.
#
# This project focuses on analyzing patient information and identifying patterns in drug prescriptions. The dataset contains patient characteristics such as age, sex, blood pressure, cholesterol level, and the Sodium-to-Potassium (Na_to_K) ratio.
#
# The main objective of this project is to understand the prescription patterns through Exploratory Data Analysis (EDA) and build a machine learning classification model that can predict the appropriate drug category for a patient.
#
# The project follows a complete data science workflow, starting from data acquisition and data understanding, followed by data preprocessing, exploratory data analysis, visualization, feature preparation, model building, model evaluation, and final prediction.

# %% [markdown]
# # 2. Problem Statement
#
# The objective of this project is to analyze patient-related information and predict the drug prescribed to a patient based on their characteristics.
#
# The dataset contains different patient attributes such as:
#
# - Age
# - Sex
# - Blood Pressure (BP)
# - Cholesterol
# - Na_to_K ratio
#
# The target variable is the **Drug** category.
#
# This is a **Multi-Class Classification** problem because the target variable contains multiple drug categories.
#
# The project will first analyze the relationship between patient characteristics and drug prescriptions using Exploratory Data Analysis (EDA). After that, machine learning classification models will be trained and evaluated to identify the model that performs best in predicting the prescribed drug.

# %% [markdown]
# # 3. My Role
#
# As a Data Science Intern, my role in this project is to analyze the patient health dataset and develop a Machine Learning solution for drug classification.
#
# My responsibilities include:
#
# - Understanding the business problem and the given dataset.
# - Performing data acquisition and data understanding.
# - Checking the dataset for missing values and duplicate records.
# - Performing data preprocessing wherever required.
# - Conducting Exploratory Data Analysis (EDA).
# - Analyzing patient characteristics and drug prescription patterns.
# - Creating appropriate visualizations using Matplotlib and Seaborn.
# - Identifying relationships between patient health metrics and prescribed drugs.
# - Preparing the data for Machine Learning.
# - Building multiple classification models.
# - Evaluating and comparing the performance of the models.
# - Selecting the best-performing model based on the Accuracy Score.
# - Using the selected model to predict the appropriate drug category.

# %% [markdown]
# # 4. Project Deliverables
#
# **Deliverable:** Drug Classification
#
# **Machine Learning Task:** Multi-Class Classification
#
# **Target Variable:** Drug
#
# **Win Condition:** N/A (Best Possible Model)
#
# **Evaluation Metric:** Accuracy Score

# %% [markdown]
# # 5. Data Description
#
# The dataset contains information about the health condition of patients, including their age, sex, blood pressure, cholesterol level, and Na_to_K ratio.
#
# These health metrics are important factors for determining the appropriate drug for a patient while minimizing the possibility of side effects.
#
# The dataset contains the following features:
#
# - **Age:** Age of the patient.
# - **Sex:** Gender of the patient.
# - **BP:** Blood pressure category of the patient.
# - **Cholesterol:** Cholesterol level of the patient.
# - **Na_to_K:** Sodium-to-Potassium ratio.
# - **Drug:** Drug prescribed to the patient.
#
# The `Drug` column is the target variable that needs to be predicted.

# %% [markdown]
# ## Importing Libraries

# %%
# Importing Pandas for data analysis and manipulation
import pandas as pd

# Importing NumPy for numerical operations
import numpy as np

# Importing Matplotlib for data visualization
import matplotlib.pyplot as plt

# Importing Seaborn for statistical data visualization
import seaborn as sns

# Displaying plots directly inside the Jupyter Notebook
# %matplotlib inline

# Importing warnings to handle unnecessary warning messages
import warnings
warnings.filterwarnings("ignore")

# Setting Pandas options to display all columns
pd.set_option('display.max_columns', None)

# Setting Pandas options to display all rows
pd.set_option('display.max_rows', None)

# Removing restrictions over chained assignment operations
pd.set_option('mode.chained_assignment', None)

# %% [markdown]
# # Data Acquisition
#
# We have the health metrics of patients, which are essential factors for determining the appropriate drug without causing unwanted side effects.
#
# The train dataset contains 160 rows and 7 columns.
# The `Drug` column is the target variable.

# %%
# Loading the training dataset

train = pd.read_csv("/Users/suchismitarout/Downloads/drug_train.csv")

# %%
# Displaying the first five rows of the dataset

train.head()
# Out:
#     Id  Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   79   32   F     LOW      NORMAL   10.840  drugX
# 1  197   52   M  NORMAL        HIGH    9.894  drugX
# 2   38   39   F  NORMAL      NORMAL    9.709  drugX
# 3   24   33   F     LOW        HIGH   33.486  DrugY
# 4  122   34   M  NORMAL        HIGH   22.456  DrugY

# %%
# Displaying the last five rows of the dataset

train.tail()
# Out:
#       Id  Age Sex      BP Cholesterol  Na_to_K   Drug
# 155  106   22   M  NORMAL        HIGH   11.953  drugX
# 156   14   50   F  NORMAL        HIGH   12.703  drugX
# 157   92   29   F    HIGH        HIGH   29.450  DrugY
# 158  179   67   F  NORMAL        HIGH   15.891  DrugY
# 159  102   28   F     LOW        HIGH   13.127  drugC

# %%
# Checking the number of rows and columns in the dataset

train.shape
# Out:
# (160, 7)

# %%
# Getting the names of all columns in the dataset

train.columns
# Out:
# Index(['Id', 'Age', 'Sex', 'BP', 'Cholesterol', 'Na_to_K', 'Drug'], dtype='object')

# %%
# Checking the data type of each column

train.dtypes
# Out:
# Id               int64
# Age              int64
# Sex             object
# BP              object
# Cholesterol     object
# Na_to_K        float64
# Drug            object
# dtype: object

# %%
# Checking the information of the dataset

train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           160 non-null    int64
#  1   Age          160 non-null    int64
#  2   Sex          160 non-null    object
#  3   BP           160 non-null    object
#  4   Cholesterol  160 non-null    object
#  5   Na_to_K      160 non-null    float64
#  6   Drug         160 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 8.9+ KB

# %%
# Checking the number of missing values in each column

train.isnull().sum()
# Out:
# Id             0
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64

# %%
# Checking the number of duplicate records

train.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Checking the number of unique values in each column

train.nunique()
# Out:
# Id             160
# Age             53
# Sex              2
# BP               3
# Cholesterol      2
# Na_to_K        159
# Drug             5
# dtype: int64

# %%
# Getting the statistical summary of numerical columns

train.describe()
# Out:
#                Id         Age     Na_to_K
# count  160.000000  160.000000  160.000000
# mean    99.075000   45.387500   16.194987
# std     59.374894   16.101481    7.254689
# min      0.000000   15.000000    6.269000
# 25%     45.500000   32.000000   10.445250
# 50%    100.500000   46.000000   14.076500
# 75%    149.500000   58.250000   19.480750
# max    199.000000   74.000000   38.247000

# %%
# Getting the statistical summary of categorical columns

train.describe(include='object')
# Out:
#         Sex    BP Cholesterol   Drug
# count   160   160         160    160
# unique    2     3           2      5
# top       M  HIGH        HIGH  DrugY
# freq     83    62          88     76

# %%
# Checking the unique values present in each categorical column

print("Sex:", train['Sex'].unique())
print("BP:", train['BP'].unique())
print("Cholesterol:", train['Cholesterol'].unique())
print("Drug:", train['Drug'].unique())
# Out:
# Sex: ['F' 'M']
# BP: ['LOW' 'NORMAL' 'HIGH']
# Cholesterol: ['NORMAL' 'HIGH']
# Drug: ['drugX' 'DrugY' 'drugC' 'drugA' 'drugB']

# %% [markdown]
# # **Observation:**
#
# - The dataset contains patient health information such as Age, Sex, BP, Cholesterol, Na_to_K, and Drug.
# - The dataset contains both numerical and categorical features.
# - Age and Na_to_K are numerical features, while Sex, BP, Cholesterol, and Drug are categorical features.
# - There are no missing values in the dataset.
# - There are no duplicate records in the dataset.
# - The categorical columns contain a limited number of unique categories.
# - Drug is the target variable that will be used for drug classification.

# %% [markdown]
# ## Detailed Numerical Analysis

# %%
# Checking the statistical measures of Age

print("Minimum Age:", train['Age'].min())
print("Maximum Age:", train['Age'].max())
print("Mean Age:", train['Age'].mean())
print("Median Age:", train['Age'].median())
print("Standard Deviation of Age:", train['Age'].std())
# Out:
# Minimum Age: 15
# Maximum Age: 74
# Mean Age: 45.3875
# Median Age: 46.0
# Standard Deviation of Age: 16.101481435026898

# %%
# Checking the statistical measures of Na_to_K

print("Minimum Na_to_K:", train['Na_to_K'].min())
print("Maximum Na_to_K:", train['Na_to_K'].max())
print("Mean Na_to_K:", train['Na_to_K'].mean())
print("Median Na_to_K:", train['Na_to_K'].median())
print("Standard Deviation of Na_to_K:", train['Na_to_K'].std())
# Out:
# Minimum Na_to_K: 6.269
# Maximum Na_to_K: 38.247
# Mean Na_to_K: 16.1949875
# Median Na_to_K: 14.0765
# Standard Deviation of Na_to_K: 7.254689171039394

# %% [markdown]
# # **Observation:**
#
# The statistical measures show the central tendency and spread of the numerical variables Age and Na_to_K.
#
# The minimum and maximum values show the range of the variables, while the mean and median help us understand their central values. Standard deviation indicates the amount of variation in the data.

# %% [markdown]
# ## Categorical Analysis

# %%
# Checking the distribution of patients by sex

train['Sex'].value_counts()
# Out:
# Sex
# M    83
# F    77
# Name: count, dtype: int64

# %%
# Checking the distribution of patients by blood pressure category

train['BP'].value_counts()
# Out:
# BP
# HIGH      62
# NORMAL    51
# LOW       47
# Name: count, dtype: int64

# %%
# Checking the distribution of patients by cholesterol level

train['Cholesterol'].value_counts()
# Out:
# Cholesterol
# HIGH      88
# NORMAL    72
# Name: count, dtype: int64

# %%
# Checking the distribution of patients by drug category

train['Drug'].value_counts()
# Out:
# Drug
# DrugY    76
# drugX    43
# drugA    17
# drugB    13
# drugC    11
# Name: count, dtype: int64

# %%
# Checking the frequency of each age

train['Age'].value_counts()
# Out:
# Age
# 39    6
# 28    6
# 23    6
# 47    6
# 32    5
# 49    5
# 60    5
# 37    5
# 50    5
# 58    5
# 72    4
# 24    4
# 57    4
# 67    4
# 31    4
# 45    4
# 41    4
# 34    4
# 56    4
# 22    4
# 68    3
# 15    3
# 43    3
# 74    3
# 51    3
# 20    3
# 40    3
# 65    3
# 61    3
# 64    3
# 69    2
# 70    2
# 46    2
# 42    2
# 48    2
# 73    2
# 52    2
# 36    2
# 53    2
# 62    2
# 59    2
# 35    2
# 26    2
# 38    1
# 63    1
# 30    1
# 16    1
# 21    1
# 18    1
# 33    1
# 66    1
# 55    1
# 29    1
# Name: count, dtype: int64

# %% [markdown]
# # **Observation:**
#
# The `value_counts()` results show the distribution of patients across the categorical variables Sex, BP, Cholesterol, Age, and Drug. These distributions give us an initial understanding of the patient population and prescription categories.

# %% [markdown]
# ## Frequency Analysis of Categorical Variables

# %%
# Checking the percentage distribution of categorical variables

print("Sex Percentage:")
print(train['Sex'].value_counts(normalize=True) * 100)

print("\nBlood Pressure Percentage:")
print(train['BP'].value_counts(normalize=True) * 100)

print("\nCholesterol Percentage:")
print(train['Cholesterol'].value_counts(normalize=True) * 100)

print("\nDrug Percentage:")
print(train['Drug'].value_counts(normalize=True) * 100)
# Out:
# Sex Percentage:
# Sex
# M    51.875
# F    48.125
# Name: proportion, dtype: float64
#
# Blood Pressure Percentage:
# BP
# HIGH      38.750
# NORMAL    31.875
# LOW       29.375
# Name: proportion, dtype: float64
#
# Cholesterol Percentage:
# Cholesterol
# HIGH      55.0
# NORMAL    45.0
# Name: proportion, dtype: float64
#
# Drug Percentage:
# Drug
# DrugY    47.500
# drugX    26.875
# drugA    10.625
# drugB     8.125
# drugC     6.875
# Name: proportion, dtype: float64

# %% [markdown]
# ## **Observation:**
#
# The frequency and percentage distributions provide an overall understanding of the categorical variables.
#
# They show how patients are distributed across sex, blood pressure, cholesterol, and drug categories. These distributions will help us understand prescription patterns in the later analysis.

# %% [markdown]
# # Data Visualization
# ## Categorical Data Visualization

# %%
# Visualizing the distribution of patients by sex

plt.figure(figsize=(6,5))
sns.countplot(x='Sex', data=train)
plt.title('Distribution of Patients by Sex')
plt.xlabel('Sex')
plt.ylabel('Number of Patients')
plt.show()

# %%
# Visualizing the distribution of patients by blood pressure

plt.figure(figsize=(7,5))
sns.countplot(x='BP', data=train)
plt.title('Distribution of Patients by Blood Pressure')
plt.xlabel('Blood Pressure')
plt.ylabel('Number of Patients')
plt.show()

# %%
# Visualizing the distribution of patients by cholesterol level

plt.figure(figsize=(7,5))
sns.countplot(x='Cholesterol', data=train)
plt.title('Distribution of Patients by Cholesterol')
plt.xlabel('Cholesterol')
plt.ylabel('Number of Patients')
plt.show()

# %%
# Visualizing the distribution of patients by drug

plt.figure(figsize=(8,5))
sns.countplot(x='Drug', data=train, order=train['Drug'].value_counts().index)
plt.title('Distribution of Drugs')
plt.xlabel('Drug')
plt.ylabel('Number of Patients')
plt.show()

# %% [markdown]
# # **Observation:**
#
# - The count plots show the distribution of patients across Sex, BP, Cholesterol, and Drug categories.
# - The categories are not equally distributed.
# - The Drug plot helps identify the most and least frequently prescribed drug categories.
# - The BP and Cholesterol plots show the distribution of patients across their respective health categories.

# %% [markdown]
# ## Numerical Data Visualization

# %%
# Visualizing the distribution of patients by age

plt.figure(figsize=(15, 12))

sns.countplot(
    x='Age',
    data=train,
    order=train['Age'].value_counts().index
)

plt.title('Distribution of Patients by Age')
plt.xlabel('Age')
plt.ylabel('Number of Patients')

plt.show()

# %%
# Visualizing the distribution of Na_to_K values

plt.figure(figsize=(10,6))
sns.histplot(train['Na_to_K'], bins=10, kde=True)
plt.title('Distribution of Na_to_K')
plt.xlabel('Na_to_K')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## **Observation:**
#
# The histograms show how the numerical values are distributed across the dataset.
#
# The Age histogram shows the distribution of patient ages, while the Na_to_K histogram shows the distribution of sodium-to-potassium ratios.
#
# These plots help us identify where most observations are concentrated and whether there are values that appear unusually high or low.

# %% [markdown]
# ## Box Plot Analysis

# %%
# Comparing Na_to_K values across different drug categories

plt.figure(figsize=(10,6))
sns.boxplot(x='Drug', y='Na_to_K', data=train)
plt.title('Na_to_K Distribution Across Drug Categories')
plt.xlabel('Drug')
plt.ylabel('Na_to_K')
plt.show()

# %% [markdown]
# ## **Observation:**
#
# The box plot compares the distribution of Na_to_K values across the different drug categories.
#
# It allows us to compare the median, spread, and possible unusually high or low Na_to_K values for each drug category.

# %%
# Creating a box plot for Na_to_K

plt.figure(figsize=(8,5))
sns.boxplot(x=train['Na_to_K'])
plt.title('Box Plot of Na_to_K')
plt.xlabel('Na_to_K')
plt.show()

# %% [markdown]
# # **Observation:**
#
# The box plots show the central tendency, spread, and possible unusually high or low values of Age and Na_to_K. The Na_to_K box plot will be particularly useful later when we identify outliers using the IQR method.

# %%
#1 How many male and female patients are present?

train['Sex'].value_counts()
# Out:
# Sex
# M    83
# F    77
# Name: count, dtype: int64

# %%
#2 What percentage of patients belongs to each sex?

train['Sex'].value_counts(normalize=True) * 100
# Out:
# Sex
# M    51.875
# F    48.125
# Name: proportion, dtype: float64

# %% [markdown]
# #### **Observation:**
#
# The above results show the number and percentage of male and female patients in the dataset.

# %%
#3 How many patients fall under each blood pressure category: LOW, NORMAL, and HIGH?

train['BP'].value_counts()
# Out:
# BP
# HIGH      62
# NORMAL    51
# LOW       47
# Name: count, dtype: int64

# %% [markdown]
# #### **Observation:**
#
# The above results show the number and percentage of male and female patients in the dataset.

# %%
#4 What is the distribution of patients by cholesterol level?

train['Cholesterol'].value_counts()
# Out:
# Cholesterol
# HIGH      88
# NORMAL    72
# Name: count, dtype: int64

# %% [markdown]
# #### **Observation:**
#
# The result shows the distribution of patients across the different cholesterol categories.

# %%
#5 Which drug is prescribed most frequently?

train['Drug'].value_counts()
# Out:
# Drug
# DrugY    76
# drugX    43
# drugA    17
# drugB    13
# drugC    11
# Name: count, dtype: int64

# %%
#6 What percentage of patients is prescribed each drug?

train['Drug'].value_counts(normalize=True) * 100
# Out:
# Drug
# DrugY    47.500
# drugX    26.875
# drugA    10.625
# drugB     8.125
# drugC     6.875
# Name: proportion, dtype: float64

# %% [markdown]
# #### **Observation:**
#
# The results show the frequency and percentage of patients prescribed each drug. The drug with the highest count is the most frequently prescribed drug.

# %%
#7 What are the minimum, maximum, mean, median, and standard deviation of Na_to_K?

print("Minimum:", train['Na_to_K'].min())
print("Maximum:", train['Na_to_K'].max())
print("Mean:", train['Na_to_K'].mean())
print("Median:", train['Na_to_K'].median())
print("Standard Deviation:", train['Na_to_K'].std())
# Out:
# Minimum: 6.269
# Maximum: 38.247
# Mean: 16.1949875
# Median: 14.0765
# Standard Deviation: 7.254689171039394

# %% [markdown]
# #### **Observation:**
#
# The above statistical measures describe the central tendency and variation of the Na_to_K feature.

# %%
#8 Which five patients have the highest Na_to_K values?

train.sort_values(by='Na_to_K', ascending=False).head(5)
# Out:
#       Id  Age Sex    BP Cholesterol  Na_to_K   Drug
# 19    96   58   F   LOW        HIGH   38.247  DrugY
# 86   184   18   F  HIGH        HIGH   37.188  DrugY
# 17    98   20   M  HIGH      NORMAL   35.639  DrugY
# 153  188   65   M  HIGH      NORMAL   34.997  DrugY
# 55   194   46   F  HIGH        HIGH   34.686  DrugY

# %%
#9 Which five patients have the lowest Na_to_K values?

train.sort_values(by='Na_to_K', ascending=True).head(5)
# Out:
#       Id  Age Sex      BP Cholesterol  Na_to_K   Drug
# 16   140   49   M    HIGH      NORMAL    6.269  drugA
# 39   111   47   F  NORMAL      NORMAL    6.683  drugX
# 139  193   72   M     LOW        HIGH    6.769  drugC
# 24    35   46   M  NORMAL      NORMAL    7.285  drugX
# 136  129   32   F  NORMAL        HIGH    7.477  drugX

# %% [markdown]
# #### **Observation:**
#
# The first output displays the five patients with the highest Na_to_K values, while the second output displays the five patients with the lowest Na_to_K values.

# %%
#10 Create the following age groups:
# Under 20
# 20–29
# 30–39
# 40–49
# 50–59
# 60 and above

bins = [0, 19, 29, 39, 49, 59, float('inf')]

labels = ['Under 20', '20-29', '30-39', '40-49', '50-59', '60 and above']

train['Age_Group'] = pd.cut(train['Age'], bins=bins, labels=labels)

train['Age_Group'].value_counts().sort_index()
# Out:
# Age_Group
# Under 20         5
# 20-29           27
# 30-39           31
# 40-49           31
# 50-59           28
# 60 and above    38
# Name: count, dtype: int64

# %%
#11 Which age group contains the highest number of patients?

train['Age_Group'].value_counts().idxmax()
# Out:
# '60 and above'

# %% [markdown]
# **Observation:**
#
# The patients are divided into the specified age groups. The frequency distribution shows the number of patients in each age group, and the second result identifies the age group containing the highest number of patients.

# %%
#12 What is the average Na_to_K value for male and female patients?

train.groupby('Sex')['Na_to_K'].mean()
# Out:
# Sex
# F    17.391117
# M    15.085325
# Name: Na_to_K, dtype: float64

# %% [markdown]
# **Observation:**
#
# The result shows the average Na_to_K value for male and female patients, allowing us to compare the average Na_to_K levels between the two sex categories.

# %%
#13 What is the average age of patients prescribed each drug?

train.groupby('Drug')['Age'].mean()
# Out:
# Drug
# DrugY    45.500000
# drugA    36.176471
# drugB    62.461538
# drugC    44.818182
# drugX    43.813953
# Name: Age, dtype: float64

# %% [markdown]
# **Observation:**
#
# The result shows the average age of patients for each drug category.

# %%
#14 What is the average Na_to_K value for each drug category?

train.groupby('Drug')['Na_to_K'].mean()
# Out:
# Drug
# DrugY    22.141697
# drugA    10.553235
# drugB    11.592769
# drugC    10.769000
# drugX    10.694395
# Name: Na_to_K, dtype: float64

# %%
#15 Which drug category has the highest median Na_to_K value?

train.groupby('Drug')['Na_to_K'].median()
train.groupby('Drug')['Na_to_K'].median().idxmax()
# Out:
# 'DrugY'

# %% [markdown]
# **Observation:**
#
# The first result shows the average Na_to_K value for each drug category.
#
# The median values provide another comparison of Na_to_K across drug categories. The final result identifies the drug category with the highest median Na_to_K value.

# %%
#16 What is the most frequently prescribed drug for male patients and female patients separately?

pd.crosstab(train['Sex'], train['Drug'])
# Out:
# Drug  DrugY  drugA  drugB  drugC  drugX
# Sex
# F        41      6      5      3     22
# M        35     11      8      8     21

# %% [markdown]
# **Observation:**
#
# The cross-tabulation shows the number of patients receiving each drug for each sex. The second result identifies the most frequently prescribed drug separately for male and female patients.

# %%
#17 How does drug prescription vary across the three blood pressure categories?

pd.crosstab(train['BP'], train['Drug'])
# Out:
# Drug    DrugY  drugA  drugB  drugC  drugX
# BP
# HIGH       32     17     13      0      0
# LOW        24      0      0     11     12
# NORMAL     20      0      0      0     31

# %%
#18 Which drug is most commonly prescribed to patients with high blood pressure?

train[train['BP'] == 'HIGH']['Drug'].value_counts()
# Out:
# Drug
# DrugY    32
# drugA    17
# drugB    13
# Name: count, dtype: int64

# %%
#19 Which drug is most commonly prescribed to patients with low blood pressure?

train[train['BP'] == 'LOW']['Drug'].value_counts()
# Out:
# Drug
# DrugY    24
# drugX    12
# drugC    11
# Name: count, dtype: int64

# %% [markdown]
# **Observation:**
#
# The cross-tabulation shows how drug prescriptions vary across LOW, NORMAL, and HIGH blood pressure categories.
#
# The additional results identify the most frequently prescribed drug among patients with HIGH blood pressure and among patients with LOW blood pressure.

# %%
#20 How does drug prescription differ between patients with HIGH and NORMAL cholesterol?

pd.crosstab(train['Cholesterol'], train['Drug'])
# Out:
# Drug         DrugY  drugA  drugB  drugC  drugX
# Cholesterol
# HIGH            43      8      7     11     19
# NORMAL          33      9      6      0     24

# %%
#21 How many patients have both high blood pressure and high cholesterol?

high_bp_high_cholesterol = train[
    (train['BP'] == 'HIGH') &
    (train['Cholesterol'] == 'HIGH')
]

len(high_bp_high_cholesterol)
# Out:
# 29

# %%
#22 What percentage of high-blood-pressure patients also have high cholesterol?

high_bp_patients = train[train['BP'] == 'HIGH']

(high_bp_high_cholesterol.shape[0] / high_bp_patients.shape[0]) * 100
# Out:
# 46.774193548387096

# %% [markdown]
# **Observation:**
#
# The first result gives the number of patients who have both HIGH blood pressure and HIGH cholesterol.
#
# The second result gives the percentage of HIGH blood pressure patients who also have HIGH cholesterol.

# %%
#23 What is the average Na_to_K value for every combination of blood pressure and cholesterol?

train.groupby(['BP', 'Cholesterol'])['Na_to_K'].mean()
# Out:
# BP      Cholesterol
# HIGH    HIGH           18.000724
#         NORMAL         16.767848
# LOW     HIGH           16.550400
#         NORMAL         17.018364
# NORMAL  HIGH           14.964382
#         NORMAL         12.875588
# Name: Na_to_K, dtype: float64

# %%
#24 Which blood pressure and cholesterol combination has the highest average Na_to_K?

train.groupby(['BP', 'Cholesterol'])['Na_to_K'].mean().idxmax()
# Out:
# ('HIGH', 'HIGH')

# %% [markdown]
# **Observation:**
#
# The first result shows the average Na_to_K value for every combination of blood pressure and cholesterol.
#
# The second result identifies the BP and Cholesterol combination with the highest average Na_to_K.

# %%
#25 For each drug, calculate the number of male and female patients.

pd.crosstab(train['Drug'], train['Sex'])
# Out:
# Sex     F   M
# Drug
# DrugY  41  35
# drugA   6  11
# drugB   5   8
# drugC   3   8
# drugX  22  21

# %%
#26 For each drug, identify the youngest and oldest patient.

train.groupby('Drug')['Age'].agg(['min', 'max'])
# Out:
#        min  max
# Drug
# DrugY   15   74
# drugA   20   50
# drugB   51   74
# drugC   16   72
# drugX   15   72

# %% [markdown]
# **Observation:**
#
# The cross-tabulation shows the number of male and female patients prescribed each drug.
# And the minimum and maximum age of patients prescribed each drug.

# %%
#27 How many patients aged above 50 are prescribed each drug?

train[train['Age'] > 50]['Drug'].value_counts()
# Out:
# Drug
# DrugY    31
# drugX    14
# drugB    13
# drugC     3
# Name: count, dtype: int64

# %%
#28 Which drug is most frequently prescribed to patients aged 60 or above?

train[train['Age'] >= 60]['Drug'].value_counts()
# Out:
# Drug
# DrugY    20
# drugB     8
# drugX     8
# drugC     2
# Name: count, dtype: int64

# %% [markdown]
# **Observation:**
#
# The first result shows the number of patients above 50 years of age prescribed each drug.
#
# The second result shows the drug distribution among patients aged 60 or above and helps identify the most frequently prescribed drug in this age group.

# %%
#29 Compare the drug distribution of patients below 40 with patients aged 40 or above.

age_drug = pd.crosstab(
    pd.cut(
        train['Age'],
        bins=[0, 39, float('inf')],
        labels=['Below 40', '40 or above']
    ),
    train['Drug']
)

age_drug.plot(kind='bar', figsize=(10,6))

plt.title('Drug Distribution by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Number of Patients')
plt.legend(title='Drug')
plt.show()

# %%
#30 Create the following Na_to_K categories:
# Low: below 10
# Moderate: 10 to below 20
# High: 20 and above

na_to_k_bins = [0, 10, 20, float('inf')]

na_to_k_labels = ['Low', 'Moderate', 'High']

train['Na_to_K_Category'] = pd.cut(
    train['Na_to_K'],
    bins=na_to_k_bins,
    labels=na_to_k_labels,
    right=False
)

train['Na_to_K_Category'].value_counts()
# Out:
# Na_to_K_Category
# Moderate    92
# High        38
# Low         30
# Name: count, dtype: int64

# %%
#31 How does drug prescription vary across the Na_to_K categories?

na_to_k_drug = pd.crosstab(
    train['Na_to_K_Category'],
    train['Drug']
)

na_to_k_drug.plot(kind='bar', figsize=(10,6))

plt.title('Drug Prescription Across Na_to_K Categories')
plt.xlabel('Na_to_K Category')
plt.ylabel('Number of Patients')
plt.legend(title='Drug')
plt.show()

# %%
#32 Which drug is most frequently prescribed to patients with a Na_to_K value of 20 or higher?

train[train['Na_to_K'] >= 20]['Drug'].value_counts()
# Out:
# Drug
# DrugY    38
# Name: count, dtype: int64

# %%
#33 Among patients with the same blood pressure level, does the average Na_to_K differ by sex?

bp_sex_natok = train.groupby(
    ['BP', 'Sex']
)['Na_to_K'].mean().unstack()

bp_sex_natok.plot(kind='bar', figsize=(10,6))

plt.title('Average Na_to_K by Blood Pressure and Sex')
plt.xlabel('Blood Pressure')
plt.ylabel('Average Na_to_K')
plt.legend(title='Sex')
plt.show()

# %%
#34 For every cholesterol category, determine which drug has the highest average patient age.

cholesterol_drug_age = train.groupby(
    ['Cholesterol', 'Drug']
)['Age'].mean()

cholesterol_drug_age
# Out:
# Cholesterol  Drug
# HIGH         DrugY    47.767442
#              drugA    38.000000
#              drugB    63.714286
#              drugC    44.818182
#              drugX    42.526316
# NORMAL       DrugY    42.545455
#              drugA    34.555556
#              drugB    61.000000
#              drugX    44.833333
# Name: Age, dtype: float64

# %%
#35 Create a cross-tabulation showing blood pressure categories against cholesterol categories.

pd.crosstab(train['BP'], train['Cholesterol'])
# Out:
# Cholesterol  HIGH  NORMAL
# BP
# HIGH           29      33
# LOW            25      22
# NORMAL         34      17

# %%
#36 Create a bar chart showing the number of patients prescribed each drug.

drug_count = train['Drug'].value_counts()

drug_count.plot(kind='bar', figsize=(8,6))

plt.title('Number of Patients Prescribed Each Drug')
plt.xlabel('Drug')
plt.ylabel('Number of Patients')
plt.show()

# %%
#37 Create a histogram showing the distribution of patient ages.

plt.figure(figsize=(10,6))

sns.histplot(train['Age'], bins=10, kde=True)

plt.title('Distribution of Patient Ages')
plt.xlabel('Age')
plt.ylabel('Number of Patients')
plt.show()

# %%
#38 Create a box plot comparing Na_to_K values across drug categories.

plt.figure(figsize=(10,6))

sns.boxplot(x='Drug', y='Na_to_K', data=train)

plt.title('Na_to_K Values Across Drug Categories')
plt.xlabel('Drug')
plt.ylabel('Na_to_K')
plt.show()

# %%
#39 Create a stacked bar chart showing drug prescriptions by blood pressure category.

bp_drug = pd.crosstab(train['BP'], train['Drug'])

bp_drug.plot(
    kind='bar',
    stacked=True,
    figsize=(10,6)
)

plt.title('Drug Prescriptions by Blood Pressure Category')
plt.xlabel('Blood Pressure')
plt.ylabel('Number of Patients')
plt.legend(title='Drug')
plt.show()

# %%
#40 Create a grouped bar chart comparing drug prescriptions between male and female patients.

sex_drug = pd.crosstab(train['Sex'], train['Drug'])

sex_drug.plot(
    kind='bar',
    figsize=(10,6)
)

plt.title('Drug Prescriptions by Sex')
plt.xlabel('Sex')
plt.ylabel('Number of Patients')
plt.legend(title='Drug')
plt.show()

# %%
#41 Create a heatmap showing the number of patients for every blood pressure and cholesterol combination.

bp_cholesterol = pd.crosstab(
    train['BP'],
    train['Cholesterol']
)

plt.figure(figsize=(8,6))

sns.heatmap(
    bp_cholesterol,
    annot=True,
    fmt='d'
)

plt.title('Patients by Blood Pressure and Cholesterol')
plt.xlabel('Cholesterol')
plt.ylabel('Blood Pressure')
plt.show()

# %%
#42 Is there a relationship between patient age and Na_to_K?
# Calculate the correlation between Age and Na_to_K.

train[['Age', 'Na_to_K']].corr()
# Out:
#               Age   Na_to_K
# Age      1.000000 -0.042363
# Na_to_K -0.042363  1.000000

# %%
# Support the answer using a scatter plot.

plt.figure(figsize=(10,6))

sns.scatterplot(
    x='Age',
    y='Na_to_K',
    data=train
)

plt.title('Relationship Between Age and Na_to_K')
plt.xlabel('Age')
plt.ylabel('Na_to_K')
plt.show()

# %%
#43 Which patient characteristics appear most strongly associated with each prescribed drug?

train.groupby('Drug')[['Age', 'Na_to_K']].mean()
# Out:
#              Age    Na_to_K
# Drug
# DrugY  45.500000  22.141697
# drugA  36.176471  10.553235
# drugB  62.461538  11.592769
# drugC  44.818182  10.769000
# drugX  43.813953  10.694395

# %%
# Checking the distribution of Sex for each Drug

pd.crosstab(train['Drug'], train['Sex'])
# Out:
# Sex     F   M
# Drug
# DrugY  41  35
# drugA   6  11
# drugB   5   8
# drugC   3   8
# drugX  22  21

# %%
# Checking the distribution of BP for each Drug

pd.crosstab(train['Drug'], train['BP'])
# Out:
# BP     HIGH  LOW  NORMAL
# Drug
# DrugY    32   24      20
# drugA    17    0       0
# drugB    13    0       0
# drugC     0   11       0
# drugX     0   12      31

# %%
# Checking the distribution of Cholesterol for each Drug

pd.crosstab(train['Drug'], train['Cholesterol'])
# Out:
# Cholesterol  HIGH  NORMAL
# Drug
# DrugY          43      33
# drugA           8       9
# drugB           7       6
# drugC          11       0
# drugX          19      24

# %% [markdown]
# **Observation:**
#
# The above results compare Age, Na_to_K, Sex, BP, and Cholesterol across the drug categories.
#
# These comparisons help identify which patient characteristics show noticeable differences between the prescribed drugs.

# %%
#44 Are there any unusually high or low Na_to_K values?
# Identify them using the IQR method.
Q1 = train['Na_to_K'].quantile(0.25)

Q3 = train['Na_to_K'].quantile(0.75)

IQR = Q3 - Q1

lower_limit = Q1 - 1.5 * IQR

upper_limit = Q3 + 1.5 * IQR

print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
print("Lower Limit:", lower_limit)
print("Upper Limit:", upper_limit)
# Out:
# Q1: 10.44525
# Q3: 19.48075
# IQR: 9.0355
# Lower Limit: -3.1080000000000023
# Upper Limit: 33.034000000000006

# %%
#45 Summarize the typical patient profile for each drug using age and Na_to_K.

train.groupby('Drug')[['Age', 'Na_to_K']].mean()
# Out:
#              Age    Na_to_K
# Drug
# DrugY  45.500000  22.141697
# drugA  36.176471  10.553235
# drugB  62.461538  11.592769
# drugC  44.818182  10.769000
# drugX  43.813953  10.694395

# %%
# Summarize the typical sex distribution for each drug.

pd.crosstab(train['Drug'], train['Sex'])
# Out:
# Sex     F   M
# Drug
# DrugY  41  35
# drugA   6  11
# drugB   5   8
# drugC   3   8
# drugX  22  21

# %%
# Summarize the typical blood pressure distribution for each drug.

pd.crosstab(train['Drug'], train['BP'])
# Out:
# BP     HIGH  LOW  NORMAL
# Drug
# DrugY    32   24      20
# drugA    17    0       0
# drugB    13    0       0
# drugC     0   11       0
# drugX     0   12      31

# %%
# Summarize the typical cholesterol distribution for each drug.

pd.crosstab(train['Drug'], train['Cholesterol'])
# Out:
# Cholesterol  HIGH  NORMAL
# Drug
# DrugY          43      33
# drugA           8       9
# drugB           7       6
# drugC          11       0
# drugX          19      24

# %% [markdown]
# **Observation:**
#
# The above analysis provides a profile of patients associated with each drug based on Age, Sex, BP, Cholesterol, and Na_to_K.
#
# The mean values and frequency distributions can be used together to describe the typical characteristics associated with each drug.

# %% [markdown]
# # Five Significant Insights About Prescription Patterns
#
# ### Insight 1
# The most frequently prescribed drug in the dataset is **[Drug]**, indicating that it accounts for the largest share of prescriptions.
#
# ### Insight 2
# The distribution of drug prescriptions varies across blood pressure categories, with **[Drug]** being the most frequently prescribed drug among **[BP category]** patients.
#
# ### Insight 3
# Patients with **[characteristic]** show a higher average Na_to_K value compared with **[comparison]**, indicating a difference in Na_to_K levels across these groups.
#
# ### Insight 4
# The analysis of cholesterol and blood pressure shows that the **[BP-Cholesterol combination]** combination has the highest average Na_to_K value.
#
# ### Insight 5
# The analysis of Age, Sex, BP, Cholesterol, and Na_to_K shows that **[Drug]** is mainly associated with patients having **[observed characteristics]**.

# %% [markdown]
# # Drug Prediction using Machine Learning

# %% [markdown]
# ## Replacing the drug names into integer¶

# %%
train.replace({'drugA': 0, 'drugB': 1, 'drugC': 2, 'drugX': 3, 'DrugY': 4}, inplace=True)

# %%
train['Drug'].value_counts()
# Out:
# Drug
# 4    76
# 3    43
# 0    17
# 1    13
# 2    11
# Name: count, dtype: int64

# %%
train.head()
# Out:
#     Id  Age Sex      BP Cholesterol  Na_to_K  Drug Age_Group Na_to_K_Category
# 0   79   32   F     LOW      NORMAL   10.840     3     30-39         Moderate
# 1  197   52   M  NORMAL        HIGH    9.894     3     50-59              Low
# 2   38   39   F  NORMAL      NORMAL    9.709     3     30-39              Low
# 3   24   33   F     LOW        HIGH   33.486     4     30-39             High
# 4  122   34   M  NORMAL        HIGH   22.456     4     30-39             High

# %% [markdown]
# ## Replace Cholesterol, Sex and BP with integers¶

# %%
# Replacing the cholesterol values into integer
train['Cholesterol'] = train['Cholesterol'].replace({'NORMAL': 0, 'HIGH': 1})

# %%
train['Cholesterol'].value_counts()
# Out:
# Cholesterol
# 1    88
# 0    72
# Name: count, dtype: int64

# %%
train.head()
# Out:
#     Id  Age Sex      BP  Cholesterol  Na_to_K  Drug Age_Group Na_to_K_Category
# 0   79   32   F     LOW            0   10.840     3     30-39         Moderate
# 1  197   52   M  NORMAL            1    9.894     3     50-59              Low
# 2   38   39   F  NORMAL            0    9.709     3     30-39              Low
# 3   24   33   F     LOW            1   33.486     4     30-39             High
# 4  122   34   M  NORMAL            1   22.456     4     30-39             High

# %%
# replacing the sex values into integer

train['Sex'] = train['Sex'].replace({'F': 0, 'M': 1})

# %%
train['Sex'].value_counts()
# Out:
# Sex
# 1    83
# 0    77
# Name: count, dtype: int64

# %%
train.head()
# Out:
#     Id  Age  Sex      BP  Cholesterol  Na_to_K  Drug Age_Group  \
# 0   79   32    0     LOW            0   10.840     3     30-39
# 1  197   52    1  NORMAL            1    9.894     3     50-59
# 2   38   39    0  NORMAL            0    9.709     3     30-39
# 3   24   33    0     LOW            1   33.486     4     30-39
# 4  122   34    1  NORMAL            1   22.456     4     30-39
#
#   Na_to_K_Category
# 0         Moderate
# 1              Low
# 2              Low
# 3             High
# 4             High

# %%
# Replacing the BP values into integer
train['BP'] = train['BP'].replace({'LOW': 0, 'NORMAL': 1, 'HIGH': 2})

# %%
train['BP'].value_counts()
# Out:
# BP
# 2    62
# 1    51
# 0    47
# Name: count, dtype: int64

# %%
train.head()
# Out:
#     Id  Age  Sex  BP  Cholesterol  Na_to_K  Drug Age_Group Na_to_K_Category
# 0   79   32    0   0            0   10.840     3     30-39         Moderate
# 1  197   52    1   1            1    9.894     3     50-59              Low
# 2   38   39    0   1            0    9.709     3     30-39              Low
# 3   24   33    0   0            1   33.486     4     30-39             High
# 4  122   34    1   1            1   22.456     4     30-39             High

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                160 non-null    int64
#  1   Age               160 non-null    int64
#  2   Sex               160 non-null    int64
#  3   BP                160 non-null    int64
#  4   Cholesterol       160 non-null    int64
#  5   Na_to_K           160 non-null    float64
#  6   Drug              160 non-null    int64
#  7   Age_Group         160 non-null    category
#  8   Na_to_K_Category  160 non-null    category
# dtypes: category(2), float64(1), int64(6)
# memory usage: 9.5 KB

# %% [markdown]
# ## Splitting the dataset

# %%
# Importing train_test_split from sklearn
from sklearn.model_selection import train_test_split

# %%
X = train.drop(['Sex', 'Drug'], axis=1)
y = train['Drug']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify=y)

# %%
X_train.head()
# Out:
#       Id  Age  BP  Cholesterol  Na_to_K Age_Group Na_to_K_Category
# 82   155   49   0            1   10.537     40-49         Moderate
# 24    35   46   1            0    7.285     40-49              Low
# 95   138   51   2            0   11.343     50-59         Moderate
# 58    27   49   1            0    9.381     40-49              Low
# 110  176   48   2            0   10.446     40-49         Moderate

# %%
X_train = pd.get_dummies(X_train, drop_first=True)
X_test = pd.get_dummies(X_test, drop_first=True)

X_train, X_test = X_train.align(X_test, join="left", axis=1, fill_value=0)

# %%
# Displaying the shape of training and testing data
print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
X_train.info()
X_train.columns
X_train.head()
# Out:
# X_train shape: (120, 12)
# y_train shape: (120,)
# X_test shape: (40, 12)
# y_test shape: (40,)
# <class 'pandas.core.frame.DataFrame'>
# Index: 120 entries, 82 to 107
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Id                         120 non-null    int64
#  1   Age                        120 non-null    int64
#  2   BP                         120 non-null    int64
#  3   Cholesterol                120 non-null    int64
#  4   Na_to_K                    120 non-null    float64
#  5   Age_Group_20-29            120 non-null    bool
#  6   Age_Group_30-39            120 non-null    bool
#  7   Age_Group_40-49            120 non-null    bool
#  8   Age_Group_50-59            120 non-null    bool
#  9   Age_Group_60 and above     120 non-null    bool
#  10  Na_to_K_Category_Moderate  120 non-null    bool
#  11  Na_to_K_Category_High      120 non-null    bool
# ...

# %% [markdown]
# # Classification
#
# Classification is a supervised machine learning technique used to assign
# data points to predefined classes.
#
# In this project, multiple classification algorithms are implemented and
# evaluated to identify the best-performing model for predicting the target
# variable.
#
# The following classifiers are used:
#
# 1. Logistic Regression
# 2. XGBoost Classifier
# 3. Decision Tree Classifier
# 4. Random Forest Classifier
# 5. Gradient Boosting Classifier
# 6. K-Nearest Neighbors (KNN)

# %% [markdown]
# ## 1. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression()

log_reg.fit(X_train, y_train)

prob = log_reg.predict_proba(X_test)
pred = log_reg.predict(X_test)

# %% [markdown]
# ## 2.XGBoost Classifier

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier()

xgb.fit(X_train, y_train)

prob = xgb.predict_proba(X_test)
pred = xgb.predict(X_test)

# %% [markdown]
# ## 3.Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()

dt.fit(X_train, y_train)

prob = dt.predict_proba(X_test)
pred = dt.predict(X_test)

# %% [markdown]
# ## 4.Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()

rf.fit(X_train, y_train)

prob = rf.predict_proba(X_test)
pred = rf.predict(X_test)

# %% [markdown]
# ## 5.Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier()

gb.fit(X_train, y_train)

prob = gb.predict_proba(X_test)
pred = gb.predict(X_test)

# %% [markdown]
# ## 6.K-Nearest Neighbors (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)

knn.fit(X_train, y_train)

prob = knn.predict_proba(X_test)
pred = knn.predict(X_test)

# %% [markdown]
# # Model Evaluation
#
# The performance of each classification model is evaluated using:
#
# - Accuracy Score
# - Classification Report
# - Confusion Matrix
# - ROC-AUC Curve
#
# These evaluation metrics are used to compare the performance of all
# classification algorithms and identify the best-performing model.

# %% [markdown]
# ## Import Evaluation Metrics

# %%
# Import required evaluation metrics
# To generate classification report
from sklearn.metrics import classification_report

# For plotting confusion matrix
from sklearn.metrics import confusion_matrix

# For calculating the accuracy of the model
from sklearn.metrics import accuracy_score

# To plot confusion matrix
from sklearn.metrics import ConfusionMatrixDisplay

# For Plotting the ROC curve
from sklearn.metrics import roc_curve

# %%
models = {
    "Logistic Regression": log_reg,
    "XGBoost": xgb,
    "Decision Tree": dt,
    "Random Forest": rf,
    "Gradient Boosting": gb,
    "KNN": knn
}

# %% [markdown]
# ## 1. Evaluate Logistic Regression

# %%
# Predict train and test labels for Logistic Regression
y_train_pred_count = log_reg.predict(X_train)
y_test_pred_count = log_reg.predict(X_test)

# Create confusion matrices for train and test data
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))
ConfusionMatrixDisplay.from_predictions(y_train, y_train_pred_count, values_format='.5g', cmap='YlGnBu', ax=ax1)
ConfusionMatrixDisplay.from_predictions(y_test, y_test_pred_count, values_format='.5g', cmap='YlGnBu', ax=ax2)
ax1.set_title('Train Data', size=12)
ax2.set_title('Test Data', size=12)
ax1.grid(False)
ax2.grid(False)
plt.suptitle('Confusion Matrix - Logistic Regression', size=14)
plt.show()

# %%
# Calculate the accuracy of Logistic Regression on test data
print("Accuracy score for test data using Logistic Regression is:", accuracy_score(y_test, y_test_pred_count))
# Out:
# Accuracy score for test data using Logistic Regression is: 0.75

# %%
# Generate classification report for Logistic Regression
train_report = classification_report(y_train, y_train_pred_count)
test_report = classification_report(y_test, y_test_pred_count)
print("Train Data Report")
print(train_report)
print("Test Data Report")
print(test_report)
# Out:
# Train Data Report
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92        13
#            1       0.73      0.80      0.76        10
#            2       0.67      0.25      0.36         8
#            3       0.85      0.88      0.86        32
#            4       0.95      1.00      0.97        57
#
#     accuracy                           0.89       120
#    macro avg       0.82      0.77      0.78       120
# weighted avg       0.88      0.89      0.88       120
#
# Test Data Report
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89         4
#            1       0.50      0.33      0.40         3
#            2       0.00      0.00      0.00         3
#            3       0.58      0.64      0.61        11
#            4       0.86      0.95      0.90        19
#
#     accuracy                           0.75        40
# ...

# %%
# Display classification report and confusion matrix for Logistic Regression
print("Classification Report:\n", classification_report(y_test, y_test_pred_count))
ConfusionMatrixDisplay.from_estimator(log_reg, X_test, y_test, cmap="Blues")
plt.show()
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89         4
#            1       0.50      0.33      0.40         3
#            2       0.00      0.00      0.00         3
#            3       0.58      0.64      0.61        11
#            4       0.86      0.95      0.90        19
#
#     accuracy                           0.75        40
#    macro avg       0.55      0.58      0.56        40
# weighted avg       0.69      0.75      0.71        40

# %%
# Predict probability for each class for Logistic Regression
y_test_prob = log_reg.predict_proba(X_test)

# Calculate ROC curve and AUC for each class
for i in range(5):
    y_test_class = (y_test == i).astype(int)
    fpr, tpr, thresholds = roc_curve(y_test_class, y_test_prob[:, i])
    roc_auc = np.trapezoid(tpr, fpr)
    plt.plot(fpr, tpr, label='Class {} (AUC = {:.2f})'.format(i, roc_auc))

plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Logistic Regression')
plt.legend()
plt.show()

# %% [markdown]
# ### Observation
#
# The ROC curve shows the performance of Logistic Regression for the five drug classes. The curve compares the True Positive Rate with the False Positive Rate. A higher AUC value indicates that the model is better at distinguishing the particular drug class from the other classes.

# %% [markdown]
# ## 2. Evaluate XGBoost

# %%
# Predict train and test labels for XGBoost
y_train_pred_count = xgb.predict(X_train)
y_test_pred_count = xgb.predict(X_test)

# %%
# Predict train and test labels for XGBoost
y_train_pred_count = xgb.predict(X_train)
y_test_pred_count = xgb.predict(X_test)

# Create confusion matrices for train and test data
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))
ConfusionMatrixDisplay.from_predictions(y_train, y_train_pred_count, values_format='.5g', cmap='YlGnBu', ax=ax1)
ConfusionMatrixDisplay.from_predictions(y_test, y_test_pred_count, values_format='.5g', cmap='YlGnBu', ax=ax2)
ax1.set_title('Train Data', size=12)
ax2.set_title('Test Data', size=12)
ax1.grid(False)
ax2.grid(False)
plt.suptitle('Confusion Matrix - XGBoost', size=14)
plt.show()

# %%
# Calculate the accuracy of XGBoost on test data
print("Accuracy score for test data using XGBoost is:", accuracy_score(y_test, y_test_pred_count))
# Out:
# Accuracy score for test data using XGBoost is: 0.975

# %%
# Generate classification report for XGBoost
train_report = classification_report(y_train, y_train_pred_count)
test_report = classification_report(y_test, y_test_pred_count)

print("Train Data Report")
print(train_report)

print("Test Data Report")
print(test_report)
# Out:
# Train Data Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      1.00      1.00        10
#            2       1.00      1.00      1.00         8
#            3       1.00      1.00      1.00        32
#            4       1.00      1.00      1.00        57
#
#     accuracy                           1.00       120
#    macro avg       1.00      1.00      1.00       120
# weighted avg       1.00      1.00      1.00       120
#
# Test Data Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         3
#            2       0.75      1.00      0.86         3
#            3       1.00      1.00      1.00        11
#            4       1.00      0.95      0.97        19
#
#     accuracy                           0.97        40
# ...

# %%
# Display classification report and confusion matrix for XGBoost
print("Classification Report:\n", classification_report(y_test, y_test_pred_count))
ConfusionMatrixDisplay.from_estimator(xgb, X_test, y_test, cmap="Blues")
plt.show()
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         3
#            2       0.75      1.00      0.86         3
#            3       1.00      1.00      1.00        11
#            4       1.00      0.95      0.97        19
#
#     accuracy                           0.97        40
#    macro avg       0.95      0.99      0.97        40
# weighted avg       0.98      0.97      0.98        40

# %%
# Predict probability for each class for XGBoost
y_test_prob = xgb.predict_proba(X_test)

# Calculate ROC curve and AUC for each class
for i in range(5):
    y_test_class = (y_test == i).astype(int)
    fpr, tpr, thresholds = roc_curve(y_test_class, y_test_prob[:, i])
    roc_auc = np.trapezoid(tpr, fpr)
    plt.plot(fpr, tpr, label='Class {} (AUC = {:.2f})'.format(i, roc_auc))

plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - XGBoost')
plt.legend()
plt.show()

# %% [markdown]
# ### Observation
#
# The ROC curve shows the performance of XGBoost for the five drug classes. The AUC values indicate how effectively XGBoost distinguishes each drug class from the remaining classes. Higher AUC values indicate better classification performance.

# %% [markdown]
# ## 3. Decision Tree

# %%
# Predict train and test labels for Decision Tree
y_train_pred_count = dt.predict(X_train)
y_test_pred_count = dt.predict(X_test)

# %%
# Predict train and test labels for Decision Tree
y_train_pred_count = dt.predict(X_train)
y_test_pred_count = dt.predict(X_test)

# Create confusion matrices for train and test data
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))
ConfusionMatrixDisplay.from_predictions(y_train, y_train_pred_count, values_format='.5g', cmap='YlGnBu', ax=ax1)
ConfusionMatrixDisplay.from_predictions(y_test, y_test_pred_count, values_format='.5g', cmap='YlGnBu', ax=ax2)
ax1.set_title('Train Data', size=12)
ax2.set_title('Test Data', size=12)
ax1.grid(False)
ax2.grid(False)
plt.suptitle('Confusion Matrix - Decision Tree', size=14)
plt.show()

# %%
# Calculate the accuracy of Decision Tree on test data
print("Accuracy score for test data using Decision Tree is:", accuracy_score(y_test, y_test_pred_count))
# Out:
# Accuracy score for test data using Decision Tree is: 1.0

# %%
# Generate classification report for Decision Tree
train_report = classification_report(y_train, y_train_pred_count)
test_report = classification_report(y_test, y_test_pred_count)

print("Train Data Report")
print(train_report)

print("Test Data Report")
print(test_report)
# Out:
# Train Data Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      1.00      1.00        10
#            2       1.00      1.00      1.00         8
#            3       1.00      1.00      1.00        32
#            4       1.00      1.00      1.00        57
#
#     accuracy                           1.00       120
#    macro avg       1.00      1.00      1.00       120
# weighted avg       1.00      1.00      1.00       120
#
# Test Data Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00        11
#            4       1.00      1.00      1.00        19
#
#     accuracy                           1.00        40
# ...

# %%
# Display classification report and confusion matrix for Decision Tree
print("Classification Report:\n", classification_report(y_test, y_test_pred_count))
ConfusionMatrixDisplay.from_estimator(dt, X_test, y_test, cmap="Blues")
plt.show()
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00        11
#            4       1.00      1.00      1.00        19
#
#     accuracy                           1.00        40
#    macro avg       1.00      1.00      1.00        40
# weighted avg       1.00      1.00      1.00        40

# %%
# Predict probability for each class for Decision Tree
y_test_prob = dt.predict_proba(X_test)

# Calculate ROC curve and AUC for each class
for i in range(5):
    y_test_class = (y_test == i).astype(int)
    fpr, tpr, thresholds = roc_curve(y_test_class, y_test_prob[:, i])
    roc_auc = np.trapezoid(tpr, fpr)
    plt.plot(fpr, tpr, label='Class {} (AUC = {:.2f})'.format(i, roc_auc))

plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Decision Tree')
plt.legend()
plt.show()

# %% [markdown]
# ### Observation
#
# The ROC curve represents the performance of the Decision Tree for each drug class. The AUC values show how well the model is able to distinguish each class from the other drug classes.

# %% [markdown]
# ## 4. Random Forest Classifier

# %%
# Predict train and test labels for Random Forest
y_train_pred_count = rf.predict(X_train)
y_test_pred_count = rf.predict(X_test)

# %%
# Create confusion matrices for train and test data
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))
ConfusionMatrixDisplay.from_predictions(y_train, y_train_pred_count, values_format='.5g', cmap='YlGnBu', ax=ax1)
ConfusionMatrixDisplay.from_predictions(y_test, y_test_pred_count, values_format='.5g', cmap='YlGnBu', ax=ax2)
ax1.set_title('Train Data', size=12)
ax2.set_title('Test Data', size=12)
ax1.grid(False)
ax2.grid(False)
plt.suptitle('Confusion Matrix - Random Forest', size=14)
plt.show()

# %%
# Calculate the accuracy of Random Forest on test data
print("Accuracy score for test data using Random Forest is:", accuracy_score(y_test, y_test_pred_count))
# Out:
# Accuracy score for test data using Random Forest is: 1.0

# %%
# Generate classification report for Random Forest
train_report = classification_report(y_train, y_train_pred_count)
test_report = classification_report(y_test, y_test_pred_count)

print("Train Data Report")
print(train_report)

print("Test Data Report")
print(test_report)
# Out:
# Train Data Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      1.00      1.00        10
#            2       1.00      1.00      1.00         8
#            3       1.00      1.00      1.00        32
#            4       1.00      1.00      1.00        57
#
#     accuracy                           1.00       120
#    macro avg       1.00      1.00      1.00       120
# weighted avg       1.00      1.00      1.00       120
#
# Test Data Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00        11
#            4       1.00      1.00      1.00        19
#
#     accuracy                           1.00        40
# ...

# %%
# Display classification report and confusion matrix for Random Forest
print("Classification Report:\n", classification_report(y_test, y_test_pred_count))
ConfusionMatrixDisplay.from_estimator(rf, X_test, y_test, cmap="Blues")
plt.show()
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00        11
#            4       1.00      1.00      1.00        19
#
#     accuracy                           1.00        40
#    macro avg       1.00      1.00      1.00        40
# weighted avg       1.00      1.00      1.00        40

# %%
# Predict probability for each class for Random Forest
y_test_prob = rf.predict_proba(X_test)

# Calculate ROC curve and AUC for each class
for i in range(5):
    y_test_class = (y_test == i).astype(int)
    fpr, tpr, thresholds = roc_curve(y_test_class, y_test_prob[:, i])
    roc_auc = np.trapezoid(tpr, fpr)
    plt.plot(fpr, tpr, label='Class {} (AUC = {:.2f})'.format(i, roc_auc))

plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Random Forest')
plt.legend()
plt.show()

# %% [markdown]
# ### Observation
#
# The ROC curve shows the classification performance of Random Forest for the five drug classes. The AUC values indicate the ability of the model to distinguish between the different drug classes.

# %% [markdown]
# ## 5. Gradient Boosting

# %%
# Predict train and test labels for Gradient Boosting
y_train_pred_count = gb.predict(X_train)
y_test_pred_count = gb.predict(X_test)

# %%
# Create confusion matrices for train and test data
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))
ConfusionMatrixDisplay.from_predictions(y_train, y_train_pred_count, values_format='.5g', cmap='YlGnBu', ax=ax1)
ConfusionMatrixDisplay.from_predictions(y_test, y_test_pred_count, values_format='.5g', cmap='YlGnBu', ax=ax2)
ax1.set_title('Train Data', size=12)
ax2.set_title('Test Data', size=12)
ax1.grid(False)
ax2.grid(False)
plt.suptitle('Confusion Matrix - Gradient Boosting', size=14)
plt.show()

# %%
# Calculate the accuracy of Gradient Boosting on test data
print("Accuracy score for test data using Gradient Boosting is:", accuracy_score(y_test, y_test_pred_count))
# Out:
# Accuracy score for test data using Gradient Boosting is: 1.0

# %%
# Generate classification report for Gradient Boosting
train_report = classification_report(y_train, y_train_pred_count)
test_report = classification_report(y_test, y_test_pred_count)

print("Train Data Report")
print(train_report)

print("Test Data Report")
print(test_report)
# Out:
# Train Data Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      1.00      1.00        10
#            2       1.00      1.00      1.00         8
#            3       1.00      1.00      1.00        32
#            4       1.00      1.00      1.00        57
#
#     accuracy                           1.00       120
#    macro avg       1.00      1.00      1.00       120
# weighted avg       1.00      1.00      1.00       120
#
# Test Data Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00        11
#            4       1.00      1.00      1.00        19
#
#     accuracy                           1.00        40
# ...

# %%
# Display classification report and confusion matrix for Gradient Boosting
print("Classification Report:\n", classification_report(y_test, y_test_pred_count))
ConfusionMatrixDisplay.from_estimator(gb, X_test, y_test, cmap="Blues")
plt.show()
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00        11
#            4       1.00      1.00      1.00        19
#
#     accuracy                           1.00        40
#    macro avg       1.00      1.00      1.00        40
# weighted avg       1.00      1.00      1.00        40

# %%
# Predict probability for each class for Gradient Boosting
y_test_prob = gb.predict_proba(X_test)

# Calculate ROC curve and AUC for each class
for i in range(5):
    y_test_class = (y_test == i).astype(int)
    fpr, tpr, thresholds = roc_curve(y_test_class, y_test_prob[:, i])
    roc_auc = np.trapezoid(tpr, fpr)
    plt.plot(fpr, tpr, label='Class {} (AUC = {:.2f})'.format(i, roc_auc))

plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Gradient Boosting')
plt.legend()
plt.show()

# %% [markdown]
# ### Observation
#
# The ROC curve represents the performance of Gradient Boosting for the five drug classes. The AUC values show how effectively the model separates each drug class from the remaining classes.

# %% [markdown]
# ## 6. KNN

# %%
# Predict train and test labels for KNN
y_train_pred_count = knn.predict(X_train)
y_test_pred_count = knn.predict(X_test)

# %%
# Create confusion matrices for train and test data
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))
ConfusionMatrixDisplay.from_predictions(y_train, y_train_pred_count, values_format='.5g', cmap='YlGnBu', ax=ax1)
ConfusionMatrixDisplay.from_predictions(y_test, y_test_pred_count, values_format='.5g', cmap='YlGnBu', ax=ax2)
ax1.set_title('Train Data', size=12)
ax2.set_title('Test Data', size=12)
ax1.grid(False)
ax2.grid(False)
plt.suptitle('Confusion Matrix - KNN', size=14)
plt.show()

# %%
# Calculate the accuracy of KNN on test data
print("Accuracy score for test data using KNN is:", accuracy_score(y_test, y_test_pred_count))
# Out:
# Accuracy score for test data using KNN is: 0.475

# %%
# Generate classification report for KNN
train_report = classification_report(y_train, y_train_pred_count)
test_report = classification_report(y_test, y_test_pred_count)

print("Train Data Report")
print(train_report)

print("Test Data Report")
print(test_report)
# Out:
# Train Data Report
#               precision    recall  f1-score   support
#
#            0       0.46      0.46      0.46        13
#            1       0.47      0.70      0.56        10
#            2       0.67      0.25      0.36         8
#            3       0.57      0.66      0.61        32
#            4       0.83      0.75      0.79        57
#
#     accuracy                           0.66       120
#    macro avg       0.60      0.56      0.56       120
# weighted avg       0.68      0.66      0.66       120
#
# Test Data Report
#               precision    recall  f1-score   support
#
#            0       0.20      0.25      0.22         4
#            1       0.29      0.67      0.40         3
#            2       0.67      0.67      0.67         3
#            3       0.25      0.18      0.21        11
#            4       0.71      0.63      0.67        19
#
#     accuracy                           0.47        40
# ...

# %%
# Display classification report and confusion matrix for KNN
print("Classification Report:\n", classification_report(y_test, y_test_pred_count))
ConfusionMatrixDisplay.from_estimator(knn, X_test, y_test, cmap="Blues")
plt.show()
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.20      0.25      0.22         4
#            1       0.29      0.67      0.40         3
#            2       0.67      0.67      0.67         3
#            3       0.25      0.18      0.21        11
#            4       0.71      0.63      0.67        19
#
#     accuracy                           0.47        40
#    macro avg       0.42      0.48      0.43        40
# weighted avg       0.50      0.47      0.48        40

# %%
# Predict probability for each class for KNN
y_test_prob = knn.predict_proba(X_test)

# Calculate ROC curve and AUC for each class
for i in range(5):
    y_test_class = (y_test == i).astype(int)
    fpr, tpr, thresholds = roc_curve(y_test_class, y_test_prob[:, i])
    roc_auc = np.trapezoid(tpr, fpr)
    plt.plot(fpr, tpr, label='Class {} (AUC = {:.2f})'.format(i, roc_auc))

plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - KNN')
plt.legend()
plt.show()

# %% [markdown]
# ### Observation
#
# The ROC curve shows the performance of KNN for the five drug classes. The AUC values indicate how well KNN distinguishes each drug class from the remaining classes. Higher AUC values indicate better classification performance.
